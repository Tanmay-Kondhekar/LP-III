# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Datasets/2_sales_data_sample.csv", encoding="latin1")
df
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# ORDERNUMBER            0
# QUANTITYORDERED        0
# PRICEEACH              0
# ORDERLINENUMBER        0
# SALES                  0
# ORDERDATE              0
# STATUS                 0
# QTR_ID                 0
# MONTH_ID               0
# YEAR_ID                0
# PRODUCTLINE            0
# MSRP                   0
# PRODUCTCODE            0
# CUSTOMERNAME           0
# PHONE                  0
# ADDRESSLINE1           0
# ADDRESSLINE2        2521
# CITY                   0
# STATE               1486
# POSTALCODE            76
# COUNTRY                0
# TERRITORY           1074
# CONTACTLASTNAME        0
# CONTACTFIRSTNAME       0
# DEALSIZE               0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#     ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 10        10223               37     100.00                1  3965.66
# 21        10361               20      72.55               13  1451.00
# 40        10270               21     100.00                9  4905.39
# 47        10347               30     100.00                1  3944.70
# 51        10391               24     100.00                4  2416.56
#
#           ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 10   2/20/2004 0:00  Shipped       1         2     2004  ...
# 21  12/17/2004 0:00  Shipped       4        12     2004  ...
# 40   7/19/2004 0:00  Shipped       3         7     2004  ...
# 47  11/29/2004 0:00  Shipped       4        11     2004  ...
# 51    3/9/2005 0:00  Shipped       1         3     2005  ...
#
#                                ADDRESSLINE1  ADDRESSLINE2          CITY  \
# 10                        636 St Kilda Road       Level 3     Melbourne
# ...

# %%
X = df[['QUANTITYORDERED','PRICEEACH','SALES']]
X
# Out:
#       QUANTITYORDERED  PRICEEACH    SALES
# 10                 37     100.00  3965.66
# 21                 20      72.55  1451.00
# 40                 21     100.00  4905.39
# 47                 30     100.00  3944.70
# 51                 24     100.00  2416.56
# ...               ...        ...      ...
# 2667               43      76.00  3268.00
# 2673               26      67.20  1747.20
# 2685               44     100.00  5001.92
# 2764               35     100.00  4277.35
# 2791               23      95.20  2189.60
#
# [147 rows x 3 columns]

# %%
from sklearn.cluster import KMeans

# %%
inertia = []
K = range(1,11)
for k in K:
    kmeans = KMeans(n_clusters=k)
    kmeans.fit(x_scaled)
    inertia.append(kmeans.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       3 for k in K:
#       4     kmeans = KMeans(n_clusters=k)
# ----> 5     kmeans.fit(x_scaled)
#       6     inertia.append(kmeans.inertia_)
#
# NameError: name 'x_scaled' is not defined

# %%
plt.figure(figsize=(12,8))
plt.plot(K,inertia,'bo-')
plt.xlabel('K')
plt.ylabel('Inertia')
plt.title('K Means Clustering')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 plt.figure(figsize=(12,8))
# ----> 2 plt.plot(K,inertia,'bo-')
#       3 plt.xlabel('K')
#       4 plt.ylabel('Inertia')
#
# NameError: name 'K' is not defined

# %%
df = pd.read_csv(r"Datasets/3_diabetes.csv")
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      Pedigree  Age  Outcome
# 0       0.627   50        1
# 1       0.351   31        0
# ...

# %%
df = pd.read_csv("Datasets/emails.csv")

# %%
df.shape
# Out:
# (5172, 3002)

# %%
x = df.iloc[:,1:3001]
Y = df.iloc[:,-1]

# %%
import seaborn as sns
sns.pairplot(df.iloc[:,1:1000],hue='Prediction')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 import seaborn as sns
# ----> 2 sns.pairplot(df.iloc[:,1:1000],hue='Prediction')
#
# File d:\Docs\codes\LP-III\venv\Lib\site-packages\seaborn\axisgrid.py:2119, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2117 # Set up the PairGrid
#    2118 grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 2119 grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    2120                 hue_order=hue_order, palette=palette, corner=corner,
#    2121                 height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    2123 # Add the markers here as PairGrid has figured out how many levels of the
# ...
